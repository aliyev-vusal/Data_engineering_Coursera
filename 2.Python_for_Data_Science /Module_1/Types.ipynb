# %% [markdown]
# Types

# %%
type(11)
# Out:
# int

# %%
type(11.5)
# Out:
# float

# %%
type("Vusal")
# Out:
# str

# %% [markdown]
# You can change the type of the expression in Python, this is called typecasting. You can convert an int to a float. For example, you can convert or cast the integer 2 to a float 2.0. Nothing really changes, if you cast a float to an integer, you must be careful.

# %%
float(2)
# Out:
# 2.0

# %%
int(2.1)
# Out:
# 2

# %%
str(3.2)
# Out:
# '3.2'

# %%
str(11)
# Out:
# '11'

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
"hello" =="wolrld"
# Out:
# False

# %%
6//2
# Out:
# 3

# %%
6 / 2
# Out:
# 3.0

# %%
type("Hello, World")
# Out:
# str

# %%
int("1001")
# Out:
# 1001

# %%
float("1234.56")
# Out:
# 1234.56

# %%
type(6/2)
# Out:
# float

# %%
str("123-456-7890")
# Out:
# '123-456-7890'

# %%
int(3.99)
# Out:
# 3
