# %% [markdown]
# Expressions and Variables

# %%
50-70
# Out:
# -20

# %%
25/6
# Out:
# 4.166666666666667

# %%
25 // 6
# Out:
# 4

# %%
29.6 // 6
# Out:
# 4.0

# %%
my_variable = 50 + 70
my_variable = 1
print(my_variable)
# Out:
# 1

# %%
type(my_variable)
# Out:
# int
