# %%
print("hello world")
# Out:
# hello world

# %%
one = 1
two = 2 
print (one + two)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 one = 1
#       2 two = 2
# ----> 3 print (one + two)
#
# TypeError: 'int' object is not callable
