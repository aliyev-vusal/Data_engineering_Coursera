# %%
print("hello world")
# Out:
# hello world

# %%
one = 1
two = 2 
print(one + two)
# Out:
# 3

# %%
"helloMike".find("Mike")
# Out:
# 5

# %%
my_string="Hello World!, Welcome to Data Engineering with Python."

split_text = my_string.split(" ")
split_text
# Out:
# ['Hello', 'World!,', 'Welcome', 'to', 'Data', 'Engineering', 'with', 'Python.']

# %%
2+3*4/2
# Out:
# 8.0

# %%
int(False)
# Out:
# 0

# %%
word="python"
word.upper()
# Out:
# 'PYTHON'
